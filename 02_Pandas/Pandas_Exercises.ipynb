# %% [markdown]
# # Pandas Exercises

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/MedlyticsUniversal/Data/main/Week1/diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %% [markdown]
# Read in csv above to a Pandas DataFrame named `data`.

# %%
# YOUR CODE HERE
data = pd.read_csv(url, names=names)

# %% [markdown]
# Print out the age and class of the 100th patient.

# %%
# YOUR CODE HERE
print(data['age'][99], data['class'][99])
# Out:
# 31 1

# %% [markdown]
# Write code to figure out how many people are classified as not having diabetes (class = 0).

# %%
# YOUR CODE HERE
num_normal = len(data[data['class']==0])
print(num_normal)
# Out:
# 500

# %% [markdown]
# Write code to figure out how many people are classified as having diabetes (class = 1).

# %%
# YOUR CODE HERE
num_diabetes = len(data[data['class']==1])
print(num_diabetes)
# Out:
# 268

# %% [markdown]
# What percent of patients have diabetes in this study?

# %%
# YOUR CODE HERE
print(num_diabetes/(num_diabetes+num_normal)*100)
# Out:
# 34.89583333333333

# %% [markdown]
# Print out the `"pres"` and `"class"` (no other columns) for the first 5 people.

# %%
# YOUR CODE HERE
print(data[['pres', 'class']][:5])
# Out:
#    pres  class
# 0    72      1
# 1    66      0
# 2    64      1
# 3    66      0
# 4    40      1

# %% [markdown]
# Run the cell below. It will print out the correlation among the columns.

# %%
data.corr()
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# pedi   0.033561  0.173844
# age    1.000000  0.238356
# class  0.238356  1.000000

# %% [markdown]
# What column has the highest correlation with class? Find the mean() value of that column.

# %%
# YOUR CODE HERE
plas_mean = data['plas'].mean()
print(plas_mean)
# Out:
# 120.89453125

# %% [markdown]
# Create a new DataFrame with only people that are above the mean found in the above cell.

# %%
# YOUR CODE HERE
filtered_dataframe_plas = pd.DataFrame(data[data['plas']>plas_mean])
print(filtered_dataframe_plas)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 2       8   183    64     0     0  23.3  0.672   32      1
# 4       0   137    40    35   168  43.1  2.288   33      1
# 8       2   197    70    45   543  30.5  0.158   53      1
# 9       8   125    96     0     0   0.0  0.232   54      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 759     6   190    92     0     0  35.5  0.278   66      1
# 761     9   170    74    31     0  44.0  0.403   43      1
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
#
# [349 rows x 9 columns]

# %% [markdown]
# Create a new DataFrame that only includes people who are above the average value for each column in the dataset. In other words, find the average value for each column, then find which users have values above all of these average column values.

# %%
print(data > data.mean())
# Out:
#       preg   plas   pres   skin   test   mass   pedi    age  class
# 0     True   True   True   True  False   True   True   True   True
# 1    False  False  False   True  False  False  False  False  False
# 2     True   True  False  False  False  False   True  False   True
# 3    False  False  False   True   True  False  False  False  False
# 4    False   True  False   True   True   True   True  False   True
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 763   True  False   True   True   True   True  False   True  False
# 764  False   True   True   True  False   True  False  False  False
# 765   True   True   True   True   True  False  False  False  False
# 766  False   True  False  False  False  False  False   True   True
# 767  False  False   True   True  False  False  False  False  False
#
# [768 rows x 9 columns]

# %%
# YOUR CODE HERE
data_filtered_all = pd.DataFrame(data[(data > data.mean()).all(axis=1)]).reset_index(drop=True)
print(data_filtered_all)
print(data_filtered_all.shape[0])
# Out:
#     preg  plas  pres  skin  test  mass   pedi  age  class
# 0      9   171   110    24   240  45.4  0.721   54      1
# 1      9   156    86    28   155  34.3  1.189   42      1
# 2     17   163    72    41   114  40.9  0.817   47      1
# 3      8   179    72    42   130  32.7  0.719   36      1
# 4      8   196    76    29   280  37.5  0.605   57      1
# 5     12   151    70    40   271  41.8  0.742   38      1
# 6      7   181    84    21   192  35.9  0.586   51      1
# 7     11   155    76    28   150  33.3  1.353   51      1
# 8     12   140    82    43   325  39.2  0.528   58      1
# 9      8   151    78    32   210  42.9  0.516   36      1
# 10    10   148    84    48   237  37.6  1.001   51      1
# 11     5   187    76    27   207  43.6  1.034   53      1
# 12     7   150    78    29   126  35.2  0.692   54      1
# 13     7   168    88    42   321  38.2  0.787   40      1
# 14    11   138    74    26   144  36.1  0.557   50      1
# 15     9   145    80    46   130  37.9  0.637   40      1
# 16

# %% [markdown]
# *Note: The next 3 problems were not explicitly shown in our tutorial—being able to effectively Google and look through documentation is a very important coding tool!* ¯\\\_(ツ)_/¯

# %% [markdown]
# Ignoring the index (resetting the index to 0) and using the DataFrame from the cell above, sort the values based on `"skin"`, `"test"`, and `"pedi"` values in ascending order. Please write this in one line.

# %%
# YOUR CODE HERE
sorted_data_1 = data.sort_values(by=['skin', 'test', 'pedi'], ascending=True).reset_index(drop=True)
print(sorted_data_1)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       0   102    52     0     0  25.1  0.078   21      0
# 1       6    87    80     0     0  23.2  0.084   32      0
# 2       1   173    74     0     0  36.8  0.088   38      1
# 3       2    74     0     0     0   0.0  0.102   22      0
# 4       2    99     0     0     0  22.2  0.108   23      0
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763     0   147    85    54     0  42.8  0.375   24      0
# 764     0   162    76    56   100  53.2  0.759   25      1
# 765     0   100    88    60   110  46.8  0.962   31      0
# 766     0   180    78    63    14  59.4  2.420   25      1
# 767     2   197    70    99     0  34.7  0.575   62      1
#
# [768 rows x 9 columns]

# %% [markdown]
# Now, let's find the 4 largest values for `"age"`.

# %%
# YOUR CODE HERE
data['age'].sort_values(ascending=False)[:4].reset_index(drop=True)
# Out:
# 0    81
# 1    72
# 2    70
# 3    69
# Name: age, dtype: int64

# %% [markdown]
# Find the smallest 4 values for `"pedi"` and `"plas"` in reverse order (smallest to largest).

# %%
# YOUR CODE HERE
print(data.sort_values(by=["pedi"], ascending = False)[:4]["pedi"].reset_index(drop=True))
print(data.sort_values(by=["plas"], ascending = False)[:4]["plas"].reset_index(drop=True))
print(data["plas"].sort_values(ascending = False)[:4].reset_index(drop=True))
# Out:
# 0    2.420
# 1    2.329
# 2    2.288
# 3    2.137
# Name: pedi, dtype: float64
# 0    199
# 1    198
# 2    197
# 3    197
# Name: plas, dtype: int64
# 0    199
# 1    198
# 2    197
# 3    197
# Name: plas, dtype: int64

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2d32e568-365c-48d5-a586-2fcf756ec4ef' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
